# %%
from ultralytics import YOLO

model = YOLO("Init_Model_coordinaate_corr.pt")  

results = model("image.png")

import cv2
import numpy as np

img = cv2.imread("image.png")

for box in r.boxes.xyxy.cpu().numpy():
    x1, y1, x2, y2 = map(int, box)
    poly = np.array([
        [x1, y1],
        [x2, y1],
        [x2, y2],
        [x1, y2]
    ], dtype=np.int32)

    cv2.polylines(img, [poly], True, (0, 255, 0), 2)

cv2.imshow("Detect-Polygone", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# image 1/1 c:\Users\Tim\Downloads\Studienprojekt-master\image.png: 384x640 (no detections), 25.5ms
# Speed: 3.5ms preprocess, 25.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# tensor([], device='cuda:0', size=(0, 4))
# tensor([], device='cuda:0')
# tensor([], device='cuda:0')
